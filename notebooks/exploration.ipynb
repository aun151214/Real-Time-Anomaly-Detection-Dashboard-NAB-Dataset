# %% [markdown]
# # Exploration notebook
# Load a NAB series, visualize, and try a baseline Isolation Forest.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from src.data_loader import load_nab_series
nab_root = Path('../NAB')
csv_rel = 'realKnownCause/machine_temperature_system_failure.csv'
df = load_nab_series(nab_root / 'data' / csv_rel)
df.plot(figsize=(10,4))
plt.title(csv_rel)
plt.show()
